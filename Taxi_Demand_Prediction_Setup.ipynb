# %% [markdown]
# <a href="https://colab.research.google.com/github/gborn/Taxi-Demand-Prediction/blob/main/Taxi_Demand_Prediction_Setup.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # New York Taxi Trip Data
#
# In this notebook, we download NewYork city Taxi Trip data provided by TLC from an AWS S3 bucket, and store them in Google Cloud Storage bucket after indexing on pickupdatetime column, and converting them into parquet files. Parquet is an open source column-oriented data format that is widely used in the Apache Hadoop ecosystem. This made computation on dataframe 93% faster.

# %%
import requests
import time
import json
import pandas as pd
import numpy as np

# %%
from google.colab import auth
auth.authenticate_user()

# project in Google Cloud
project_id = 'taxi-demand-prediction-333318'

# Make a unique bucket to which we'll upload the file.
# (GCS buckets are part of a single global namespace.)
bucket_name = project_id

# setup Google Cloud project
# !gcloud config set project {project_id}
# Out:
# Updated property [core/project].

# %%
from concurrent.futures import ThreadPoolExecutor
import multiprocessing as mp

def download_from_s3(fn):
    """
    Downloads New York Taxi data for a given month, and year from a public AWS S3 bucket
    Downloaded files will be stored in current file system of colab
    """
    print(f'{mp.current_process().name}: downloading {fn}')
    # !wget --header="Host: s3.amazonaws.com" --header="User-Agent: Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/96.0.4664.45 Safari/537.36" --header="Accept: text/html,application/xhtml+xml,application/xml;q=0.9,image/avif,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.9" --header="Accept-Language: en-US,en;q=0.9" "https://s3.amazonaws.com/nyc-tlc/trip+data/yellow_tripdata_{fn}.csv" -c -O 'yellow_tripdata_{fn}.csv'

def download_to_gcs():
    """
    Downloads from data from AWS S3 bucket in parallel, and
    copies files from colab to a Google Storage bucket 
    """
    # check if files are present

    # download Jan 2020 to Dec 2020 data, and Jan 2021, Feb 2021, March 2021 data parallely
    filenames = [f'2020-{i:02d}' for i in range(1, 13)] # 2020 data
    filenames.extend([f'2021-{i:02d}' for i in range(1, 4)]) # 2021 data till March

    with ThreadPoolExecutor() as pool:
        pool.map(download_from_s3, filenames)

    # bucket already exists, but incase it doesn't use the following cmd to create one
    # !gsutil mb gs://{bucket_name}

    # Copy all files to our new bucket.
    # !gsutil cp yellow_tripdata_*.csv gs://{bucket_name}/raw_data

download_to_gcs()
# Out:
# MainProcess: downloading 2020-01MainProcess: downloading 2020-02
# MainProcess: downloading 2020-03
#
# MainProcess: downloading 2020-04
# MainProcess: downloading 2020-05
# MainProcess: downloading 2020-06MainProcess: downloading 2020-07
# --2021-11-27 12:49:19--  https://s3.amazonaws.com/nyc-tlc/trip+data/yellow_tripdata_2020-05.csv
# Resolving s3.amazonaws.com (s3.amazonaws.com)... MainProcess: downloading 2020-08
#
# MainProcess: downloading 2020-09
# MainProcess: downloading 2020-10--2021-11-27 12:49:19--  https://s3.amazonaws.com/nyc-tlc/trip+data/yellow_tripdata_2020-07.csv
#
# --2021-11-27 12:49:19--  https://s3.amazonaws.com/nyc-tlc/trip+data/yellow_tripdata_2020-08.csv
# Resolving s3.amazonaws.com (s3.amazonaws.com)... Resolving s3.amazonaws.com (s3.amazonaws.com)... 54.231.137.56
# Connecting to s3.amazonaws.com (s3.amazonaws.com)|54.231.137.56|:443... MainProcess: downloading 2020-11
# 54.231.137.56
# Connecting to s3.amazonaws.com (s3.amazonaws.com)|54.231.137.56|:443... MainProcess: downloading 2020-12MainProcess: downloading 2021-01
# MainProcess: downloading 2021-02
# MainProcess: downloading 2021-03
# --2021-11-27 12:49:19--  https://s3.amazonaws.com/nyc-tlc/trip+data/yellow_tripdata_2020-11.csv
# Resolving s3.amazonaws.com (s3.amazonaws.com)... 54.231.137.56
# Connecting to s3.amazonaws.com (s3.amazonaws.com)|54.231.137.56|:443... --2021-11-27 12:49:19--  https://s3.amazonaws.com/nyc-tlc/trip+data/yellow_tripdata_2020-01.csv
# Resolving s3.amazonaws.com (s3.amazonaws.com)... 52.217.88.238
# Connecting to s3.amazonaws.com (s3.amazonaws.com)|52.217.88.238|:443... connected.
# HTTP request sent, awaiting response...
# --2021-11-27 12:49:19--  https://s3.amazonaws.com/nyc-tlc/trip+data/yellow_tripdata_2021-01.csv
# Resolving s3.amazonaws.com (s3.amazonaws.com)... 54.231.137.56
# Connecting to s3.amazonaws.com (s3.amazonaws.com)|54.231.137.56|:443... --2021-11-27 12:49:19--  https://s3.amazonaws.com/nyc-tlc/trip+data/yellow_tripdata_2020-03.csv
# Resolving s3.amazonaws.com (s3.amazonaws.com)... 54.231.137.56
# Connecting to s3.amazonaws.com (s3.amazonaws.com)|54.231.137.56|:443... connected.
# HTTP request sent, awaiting response... --2021-11-27 12:49:19--  https://s3.amazonaws.com/nyc-tlc/trip+data/yellow_tripdata_2020-04.csv
# Resolving s3.amazonaws.com (s3.amazonaws.com)... 54.231.137.0
# Connecting to s3.amazonaws.com (s3.amazonaws.com)|54.231.137.0|:443... connected.
# HTTP request sent, awaiting response... --2021-11-27 12:49:19--  https://s3.amazonaws.com/nyc-tlc/trip+data/yellow_tripdata_2020-02.csv
# Resolving s3.amazonaws.com (s3.amazonaws.com)... 52.216.107.126
# Connecting to s3.amazonaws.com (s3.amazonaws.com)|52.216.107.126|:443... connected.
# HTTP request sent, awaiting response... 52.216.107.126
# Connecting to s3.amazonaws.com (s3.amazonaws.com)|52.216.107.126|:443... connected.
# HTTP request sent, awaiting response... --2021-11-27 12:49:19--  https://s3.amazonaws.com/nyc-tlc/trip+data/yellow_tripdata_2020-06.csv
# Resolving s3.amazonaws.com (s3.amazonaws.com)... 54.231.137.56
# Connecting to s3.amazonaws.com (s3.amazonaws.com)|54.231.137.56|:443... connected.
# HTTP request sent, awaiting response... connected.
# HTTP request sent, awaiting response... connected.
# HTTP request sent, awaiting response... --2021-11-27 12:49:19--  https://s3.amazonaws.com/nyc-tlc/trip+data/yellow_tripdata_2020-09.csv
# Resolving s3.amazonaws.com (s3.amazonaws.com)... 54.231.137.56
# Connecting to s3.amazonaws.com (s3.amazonaws.com)|54.231.137.56|:443... connected.
# HTTP request sent, awaiting response... connected.
# HTTP request sent, awaiting response... --2021-11-27 12:49:19--  https://s3.amazonaws.com/nyc-tlc/trip+data/yellow_tripdata_2021-02.csv
# Resolving s3.amazonaws.com (s3.amazonaws.com)... 54.231.137.56
# Connecting to s3.amazonaws.com (s3.amazonaws.com)|54.231.137.56|:443... connected.
# HTTP request sent, awaiting response... --2021-11-27 12:49:19--  https://s3.amazonaws.com/nyc-tlc/trip+data/yellow_tripdata_2020-10.csv
# Resolving s3.amazonaws.com (s3.amazonaws.com)... 54.231.137.56
# Connecting to s3.amazonaws.com (s3.amazonaws.com)|54.231.137.56|:443... connected.
# HTTP request sent, awaiting response... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 278288608 (265M) [text/csv]
# Saving to: ‘yellow_tripdata_2020-03.csv’
#
#           yellow_tr   0%[                    ]       0  --.-KB/s               --2021-11-27 12:49:19--  https://s3.amazonaws.com/nyc-tlc/trip+data/yellow_tripdata_2021-03.csv
# Resolving s3.amazonaws.com (s3.amazonaws.com)... 54.231.137.56
# Connecting to s3.amazonaws.com (s3.amazonaws.com)|54.231.137.56|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 584190585 (557M) [text/csv]
# Saving to: ‘yellow_tripdata_2020-02.csv’
#
#           yellow_tr   0%[                    ]       0  --.-KB/s               200 OK
# Length: 31641590 (30M) [text/csv]
# Saving to: ‘yellow_tripdata_2020-05.csv’
#
#           yellow_tr   0%[                    ]       0  --.-KB/s               --2021-11-27 12:49:19--  https://s3.amazonaws.com/nyc-tlc/trip+data/yellow_tripdata_2020-12.csv
# Resolving s3.amazonaws.com (s3.amazonaws.com)... 54.231.137.56
# Connecting to s3.amazonaws.com (s3.amazonaws.com)|54.231.137.56|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 50277193 (48M) [text/csv]
# Saving to: ‘yellow_tripdata_2020-06.csv’
#
#           yellow_tr   0%[                    ]       0  --.-KB/s               200 OK
# Length: 92411545 (88M) [text/csv]
# Saving to: ‘yellow_tripdata_2020-08.csv’
#
#           yellow_tr   0%[                    ]       0  --.-KB/s               200 OK
# Length: 123394595 (118M) [text/csv]
# Saving to: ‘yellow_tripdata_2020-09.csv’
#
#           yellow_tr   0%[                    ]       0  --.-KB/s               200 OK
# Length: 73326707 (70M) [text/csv]
# Saving to: ‘yellow_tripdata_2020-07.csv’
#
#           yellow_tr   0%[                    ]       0  --.-KB/s               200 OK
# Length: 138989555 (133M) [text/csv]
# Saving to: ‘yellow_tripdata_2020-11.csv’
#
#           yellow_tr   0%[                    ]       0  --.-KB/s               200 OK
# Length: 593610736 (566M) [text/csv]
# Saving to: ‘yellow_tripdata_2020-01.csv’
#
#           yellow_tr   0%[                    ]       0  --.-KB/s               200 OK
# Length: 125981363 (120M) [text/csv]
# Saving to: ‘yellow_tripdata_2021-01.csv’
#
#           yellow_tr   0%[                    ]       0  --.-KB/s               200 OK
# Length: 21662261 (21M) [text/csv]
# Saving to: ‘yellow_tripdata_2020-04.csv’
#
#           yellow_tr   0%[                    ]       0  --.-KB/s               200 OK
# Length: 154917592 (148M) [text/csv]
# Saving to: ‘yellow_tripdata_2020-10.csv’
#
#           yellow_tr   0%[                    ]       0  --.-KB/s               200 OK
# Length: 126236413 (120M) [text/csv]
# Saving to: ‘yellow_tripdata_2021-02.csv’
#
#          yellow_tri   0%[                    ]   4.40M  22.0MB/s               200 OK
# Length: 177416284 (169M) [text/csv]
# Saving to: ‘yellow_tripdata_2021-03.csv’
#
#          yellow_tri  14%[=>                  ]   4.48M  21.5MB/s               200 OK
# Length: 134481400 (128M) [text/csv]
# Saving to: ‘yellow_tripdata_2020-12.csv’
#
# yellow_tripdata_202 100%[===================>]  20.66M  24.6MB/s    in 0.8s
#
# 2021-11-27 12:49:20 (24.6 MB/s) - ‘yellow_tripdata_2020-04.csv’ saved [21662261/21662261]
#
# yellow_tripdata_202 100%[===================>]  47.95M  54.9MB/s    in 0.9s
#
# 2021-11-27 12:49:20 (54.9 MB/s) - ‘yellow_tripdata_2020-06.csv’ saved [50277193/50277193]
#
# yellow_tripdata_202 100%[===================>]  30.17M  29.0MB/s    in 1.0s
#
# 2021-11-27 12:49:20 (29.0 MB/s) - ‘yellow_tripdata_2020-05.csv’ saved [31641590/31641590]
#
# yellow_tripdata_202 100%[===================>]  69.93M  40.2MB/s    in 1.7s
#
# 2021-11-27 12:49:21 (40.2 MB/s) - ‘yellow_tripdata_2020-07.csv’ saved [73326707/73326707]
#
# yellow_tripdata_202 100%[===================>]  88.13M  31.3MB/s    in 2.8s
#
# 2021-11-27 12:49:22 (31.3 MB/s) - ‘yellow_tripdata_2020-08.csv’ saved [92411545/92411545]
#
# yellow_tripdata_202 100%[===================>] 120.39M  33.8MB/s    in 3.6s
#
# 2021-11-27 12:49:23 (33.8 MB/s) - ‘yellow_tripdata_2021-02.csv’ saved [126236413/126236413]
#
# yellow_tripdata_202 100%[===================>] 117.68M  30.8MB/s    in 3.9s
#
# 2021-11-27 12:49:23 (29.9 MB/s) - ‘yellow_tripdata_2020-09.csv’ saved [123394595/123394595]
#
# yellow_tripdata_202 100%[===================>] 128.25M  29.6MB/s    in 4.8s
#
# 2021-11-27 12:49:24 (27.0 MB/s) - ‘yellow_tripdata_2020-12.csv’ saved [134481400/134481400]
#
# yellow_tripdata_202 100%[===================>] 120.14M  25.9MB/s    in 5.4s
#
# 2021-11-27 12:49:25 (22.1 MB/s) - ‘yellow_tripdata_2021-01.csv’ saved [125981363/125981363]
#
# yellow_tripdata_202 100%[===================>] 147.74M  28.3MB/s    in 5.5s
#
# 2021-11-27 12:49:25 (27.0 MB/s) - ‘yellow_tripdata_2020-10.csv’ saved [154917592/154917592]
#
# yellow_tripdata_202 100%[===================>] 169.20M  29.6MB/s    in 5.7s
#
# 2021-11-27 12:49:25 (29.9 MB/s) - ‘yellow_tripdata_2021-03.csv’ saved [177416284/177416284]
#
# yellow_tripdata_202 100%[===================>] 265.40M  45.8MB/s    in 7.6s
#
# 2021-11-27 12:49:27 (35.1 MB/s) - ‘yellow_tripdata_2020-03.csv’ saved [278288608/278288608]
#
# yellow_tripdata_202 100%[===================>] 132.55M  19.7MB/s    in 8.7s
#
# 2021-11-27 12:49:28 (15.2 MB/s) - ‘yellow_tripdata_2020-11.csv’ saved [138989555/138989555]
#
# yellow_tripdata_202 100%[===================>] 566.11M   101MB/s    in 10s
#
# 2021-11-27 12:49:30 (55.9 MB/s) - ‘yellow_tripdata_2020-01.csv’ saved [593610736/593610736]
#
# yellow_tripdata_202 100%[===================>] 557.13M  40.9MB/s    in 16s
#
# 2021-11-27 12:49:35 (34.5 MB/s) - ‘yellow_tripdata_2020-02.csv’ saved [584190585/584190585]
#
# Copying file://yellow_tripdata_2020-01.csv [Content-Type=text/csv]...
# ==> NOTE: You are uploading one or more large file(s), which would run
# significantly faster if you enable parallel composite uploads. This
# feature can be enabled by editing the
# "parallel_composite_upload_threshold" value in your .boto
# configuration file. However, note that if you do this large files will
# be uploaded as `composite objects
# <https://cloud.google.com/storage/docs/composite-objects>`_,which
# means that any user who downloads such objects will need to have a
# compiled crcmod installed (see "gsutil help crcmod"). This is because
# without a compiled crcmod, computing checksums on composite objects is
# so slow that gsutil disables downloads of composite objects.
#
# Copying file://yellow_tripdata_2020-02.csv [Content-Type=text/csv]...
# Copying file://yellow_tripdata_2020-03.csv [Content-Type=text/csv]...
# Copying file://yellow_tripdata_2020-04.csv [Content-Type=text/csv]...
# | [4 files][  1.4 GiB/  1.4 GiB]   86.1 MiB/s
# ==> NOTE: You are performing a sequence of gsutil operations that may
# run significantly faster if you instead use gsutil -m cp ... Please
# see the -m section under "gsutil help options" for further information
# about when gsutil -m can be advantageous.
#
# Copying file://yellow_tripdata_2020-05.csv [Content-Type=text/csv]...
# Copying file://yellow_tripdata_2020-06.csv [Content-Type=text/csv]...
# Copying file://yellow_tripdata_2020-07.csv [Content-Type=text/csv]...
# Copying file://yellow_tripdata_2020-08.csv [Content-Type=text/csv]...
# Copying file://yellow_tripdata_2020-09.csv [Content-Type=text/csv]...
# Copying file://yellow_tripdata_2020-10.csv [Content-Type=text/csv]...
# Copying file://yellow_tripdata_2020-11.csv [Content-Type=text/csv]...
# Copying file://yellow_tripdata_2020-12.csv [Content-Type=text/csv]...
# Copying file://yellow_tripdata_2021-01.csv [Content-Type=text/csv]...
# Copying file://yellow_tripdata_2021-02.csv [Content-Type=text/csv]...
# Copying file://yellow_tripdata_2021-03.csv [Content-Type=text/csv]...
# \ [15 files][  2.5 GiB/  2.5 GiB]   83.9 MiB/s
# Operation completed over 15 objects/2.5 GiB.

# %%
# Load csv data into Dask DataFrame
# !pip install dask > /dev/null
# !pip install dask[complete] >/dev/null
# !pip install gcsfs > /dev/null

from dask import dataframe as dd

trips = dd.read_csv(
    f'gs://{bucket_name}/raw_data/yellow_tripdata_*.csv',
    parse_dates=['tpep_pickup_datetime', 'tpep_dropoff_datetime'],
    dtype={
    'store_and_fwd_flag': 'str',
    'RatecodeID': 'float64',
    'VendorID': 'float64',
    'passenger_count': 'float64',
    'payment_type': 'float64'
    }
)

trips.head()
# Out:
#    VendorID tpep_pickup_datetime  ... total_amount  congestion_surcharge
# 0       1.0  2020-01-01 00:28:15  ...        11.27                   2.5
# 1       1.0  2020-01-01 00:35:39  ...        12.30                   2.5
# 2       1.0  2020-01-01 00:47:41  ...        10.80                   2.5
# 3       1.0  2020-01-01 00:55:23  ...         8.16                   0.0
# 4       2.0  2020-01-01 00:01:58  ...         4.80                   0.0
#
# [5 rows x 18 columns]

# %%
len(trips)
# Out:
# 29315124

# %%
trips.dtypes
# Out:
# VendorID                        float64
# tpep_pickup_datetime     datetime64[ns]
# tpep_dropoff_datetime    datetime64[ns]
# passenger_count                 float64
# trip_distance                   float64
# RatecodeID                      float64
# store_and_fwd_flag               object
# PULocationID                      int64
# DOLocationID                      int64
# payment_type                    float64
# fare_amount                     float64
# extra                           float64
# mta_tax                         float64
# tip_amount                      float64
# tolls_amount                    float64
# improvement_surcharge           float64
# total_amount                    float64
# congestion_surcharge            float64
# dtype: object

# %% [markdown]
# ## Store Data in Apache Parquet Format
#
# Dask encourage dataframe users to store and load data using Parquet instead of csv. [Apache Parquet](http://parquet.apache.org/) is a columnar binary format that is easy to split into multiple files (easier for parallel loading) and is generally much simpler to deal with than HDF5 (from the Dask library’s perspective). It is also a common format used by other big data systems like [Apache Spark](http://spark.apache.org/) and so is useful to interchange with other systems.

# %%
# Index data on pickup datetime column using following division
# This will help partition our data month wise
divisions = [
 '2020-01-01', '2020-02-01', '2020-03-01', '2020-04-01',
 '2020-05-01', '2020-06-01', '2020-07-01', '2020-08-01',
 '2020-09-01', '2020-10-01', '2020-11-01', '2020-12-01',
 '2021-01-01', '2021-02-01', '2021-03-01', '2021-04-01'
 ]

trips = trips.set_index('tpep_pickup_datetime', drop=False, divisions=divisions)

# save to parquet files, which we will use in upcoming notebooks for EDA, and preprocessing
trips.to_parquet(f'gs://{bucket_name}/nyctaxidata', write_index=False, append=True, ignore_divisions=False)  # save csv files using parquet format
trips = dd.read_parquet(f'gs://{bucket_name}/nyctaxidata/*.parquet')
trips.head()
# Out:
#    VendorID tpep_pickup_datetime  ... total_amount  congestion_surcharge
# 0       1.0           2020-01-01  ...        17.15                   2.5
# 1       2.0           2020-01-01  ...        22.30                   2.5
# 2       2.0           2020-01-01  ...         9.30                   2.5
# 3       2.0           2020-01-01  ...        10.30                   2.5
# 4       2.0           2020-01-01  ...        11.30                   0.0
#
# [5 rows x 18 columns]

# %%
trips.npartitions
# Out:
# 15

# %%
# In csv format this code takes around 1:30 minutes to complete for 29.3 million rows
# With parquet format it computes within 6s - 93% faster.
trips.get_partition(1).tail()
# Out:
#          VendorID tpep_pickup_datetime  ... total_amount  congestion_surcharge
# 6299468       2.0  2020-02-29 23:59:58  ...        12.36                   2.5
# 6299469       2.0  2020-02-29 23:59:58  ...        30.29                   2.5
# 6299470       2.0  2020-02-29 23:59:59  ...        12.96                   2.5
# 6299471       2.0  2020-02-29 23:59:59  ...         5.80                   0.0
# 6299472       2.0  2020-02-29 23:59:59  ...        19.75                   2.5
#
# [5 rows x 18 columns]
